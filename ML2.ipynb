# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-217c0154-a4ed-4831-8ef8-504000248978" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-217c0154-a4ed-4831-8ef8-504000248978">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
def estimate_charges(age,w,b):
  return w*age+b
def rmse(actual_charges,estimated_charges):
  return np.sqrt(np.mean((actual_charges-estimated_charges)**2))
def try_and_get(w,b):
  age = frame2.age
  estimated_charges = estimate_charges(age,w,b)
  plt.plot(age,estimated_charges,'r')
  plt.scatter(age,frame2.charges)
  plt.xlabel('Age')
  plt.ylabel('Charges')
  print(rmse(frame2.charges,estimated_charges))
  plt.show()

# %%
import pandas as pd
frame = pd.read_csv('insurance.csv')
frame2 = frame[frame.smoker == 'no']
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
sns.scatterplot(x='age', y='charges', data=frame2)
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
try_and_get(267.2489,-2091.42055)
# Out:
# 4662.505766636425

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(frame2[['age']],frame2.charges)
prediction = model.predict(frame2[['age']])
print(prediction)
# Out:
# [2719.0598744  5391.54900271 6727.79356686 ... 2719.0598744  2719.0598744
#  3520.80661289]

# %%
plt.plot(frame2.age,prediction,'r')
plt.scatter(frame2.age,frame2.charges)
plt.xlabel('Age')
plt.ylabel('Charges')
print(rmse(frame2.charges,prediction))
plt.show()
# Out:
# 4662.505766636395

# %%
model2 = LinearRegression()
model2.fit(frame2[['age','bmi','children']],frame2.charges)
prediction2 = model2.predict(frame2[['age','bmi','children']])
print(rmse(prediction2,frame2.charges))
print(prediction2)
# Out:
# 4608.470405038247
# [2724.94209163 6535.13457204 6065.27173951 ... 2134.51524931 2160.54349555
#  2898.08585583]

# %%
print(frame2)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# ...   ...     ...     ...       ...    ...        ...          ...
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
#
# [1064 rows x 7 columns]
